# %% [markdown]
# # Notebook that retrieves API data related to tracks

# %% [markdown]
# ## Imports

# %%
import base64
import pandas as pd
import requests
from time import sleep

from typing import List, Any

# %% [markdown]
# ## Methods

# %%
# Split a list into chunks of specified size
def chunk_list(data: List[Any], chunk_size: int = 0, max_chunk: int = None):
    if chunk_size > 0:
        size = chunk_size
        if max_chunk is not None:
            size = min(chunk_size, max_chunk)
    elif max_chunk is not None and max_chunk > 0:
        size = max_chunk
    else:
        size = 100  # default chunk size

    for i in range(0, len(data), size):
        yield data[i:i + size]

# %% [markdown]
# ## Reading dataset

# %%
df_treated = pd.read_csv("final_df.csv")

# %% [markdown]
# ## ReccoBeats APIs - [Get multiple track](https://reccobeats.com/docs/apis/get-tracks) and [Get multiple audio features](https://reccobeats.com/docs/apis/get-audio-features)

# %%
unique_track_id_list = df_treated["track_id"].unique()

headers = {
  'Accept': 'application/json'
}

audio_features_dataframes = []
multiple_track_dataframes = []

for chunk in chunk_list(unique_track_id_list, 40):
    # print(chunk)
    print(f"Len: {len(chunk)}")

    url_audio_features = "https://api.reccobeats.com/v1/audio-features?ids="
    url_multiple_track = "https://api.reccobeats.com/v1/track?ids="

    track_ids_str = ",".join([track_id for track_id in chunk])

    url_audio_features += track_ids_str
    url_multiple_track += track_ids_str

    response_audio_features = requests.get(url=url_audio_features, headers=headers)
    response_multiple_track = requests.get(url=url_multiple_track, headers=headers)
    
    audio_features_dataframes.append(pd.json_normalize(response_audio_features.json(), record_path="content"))
    multiple_track_dataframes.append(pd.json_normalize(response_multiple_track.json(), record_path="content"))

df_audio_features = pd.concat(audio_features_dataframes, ignore_index=True)
df_multiple_track = pd.concat(multiple_track_dataframes, ignore_index=True)

df_audio_features["track_id"] = df_audio_features["href"].str.rpartition("/")[2]
df_multiple_track["track_id"] = df_multiple_track["href"].str.rpartition("/")[2]
# Out:
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 40
# Len: 30

# %% [markdown]
# ## Checking results

# %%
display(df_audio_features.head(5))
display(df_multiple_track.head(5))
# Out:
#                                      id  \
# 0  666543a0-04fb-40c1-845b-668beefa1a88
# 1  96758562-28d9-43de-9249-79a49b8f4994
# 2  80dd06dd-8508-4ac0-b023-d21c40fe2c5a
# 3  59935bea-5e0a-4c00-8269-b01baa8c1992
# 4  ca0b1c69-be5d-4754-a490-efba6d4911fc
#
#                                                 href          isrc  \
# 0  https://open.spotify.com/track/6RUKPb4LETWmmr3...  USQX91700278
# 1  https://open.spotify.com/track/4tHqQMWSqmL6YjX...  USSM19912814
# 2  https://open.spotify.com/track/0HmONWWIU1FXkwW...  NOG841549020
# 3  https://open.spotify.com/track/1dNIEtp7AY3oDAK...  USQX91700278
# 4  https://open.spotify.com/track/0u8aj0c4IxeVSLT...  BRSME1700003
#
#    acousticness  danceability  energy  instrumentalness   key  liveness  \
# 0       0.04980         0.617   0.635          0.000014  11.0    0.1640
# 1       0.99400         0.418   0.106          0.029200   8.0    0.1790
# 2       0.00073         0.750   0.617          0.318000   6.0    0.1050
# 3       0.03060         0.607   0.649          0.000025  11.0    0.1740
# 4       0.37400         0.854   0.682          0.000000   9.0    0.0697
#
#    loudness  mode  speechiness    tempo  valence                track_id
# 0    -6.769   0.0       0.0317  103.019    0.446  6RUKPb4LETWmmr3iAEQktW
# 1   -22.507   0.0       0.0448   46.718    0.800  4tHqQMWSqmL6YjXwsqthDI
# 2    -6.725   1.0       0.0318   89.968    0.108  0HmONWWIU1FXkwWLDpqrjl
# 3    -6.695   0.0       0.0362  102.996    0.505  1dNIEtp7AY3oDAKCGg2XkH
# 4    -5.818   0.0       0.0690   98.023    0.887  0u8aj0c4IxeVSLTUuuq9V5
#                                      id  \
# 0  666543a0-04fb-40c1-845b-668beefa1a88
# 1  96758562-28d9-43de-9249-79a49b8f4994
# 2  80dd06dd-8508-4ac0-b023-d21c40fe2c5a
# 3  59935bea-5e0a-4c00-8269-b01baa8c1992
# 4  ca0b1c69-be5d-4754-a490-efba6d4911fc
#
#                                           trackTitle  \
# 0                           Something Just Like This
# 1                                 Carol of the Bells
# 2                               Faded - Instrumental
# 3                           Something Just Like This
# 4  Você Partiu Meu Coração (feat. Anitta & Wesley...
#
#                                              artists  durationMs  \
# 0  [{'id': 'e074334e-20b0-4f9e-a212-5b5632a4e935'...      247160
# 1  [{'id': '640564f3-58c4-4b17-bd41-e228e77bf7c1'...       85266
# 2  [{'id': '0a5d81f9-b98b-46b7-84e7-7b19f340cf61'...      214013
# 3  [{'id': 'e074334e-20b0-4f9e-a212-5b5632a4e935'...      247626
# 4  [{'id': 'dd7180b0-f357-4ef8-9ea4-9861c91f4001'...      179000
#
#            isrc   ean   upc  \
# 0  USQX91700278  None  None
# 1  USSM19912814  None  None
# 2  NOG841549020  None  None
# 3  USQX91700278  None  None
# 4  BRSME1700003  None  None
#
#                                                 href  \
# 0  https://open.spotify.com/track/6RUKPb4LETWmmr3...
# 1  https://open.spotify.com/track/4tHqQMWSqmL6YjX...
# 2  https://open.spotify.com/track/0HmONWWIU1FXkwW...
# 3  https://open.spotify.com/track/1dNIEtp7AY3oDAK...
# 4  https://open.spotify.com/track/0u8aj0c4IxeVSLT...
#
#                                   availableCountries  popularity  \
# 0  AR,AU,AT,BE,BO,BR,BG,CA,CL,CO,CR,CY,CZ,DK,DO,D...          86
# 1  AR,AU,AT,BE,BO,BR,BG,CA,CL,CO,CR,CY,CZ,DK,DO,D...          80
# 2  AR,AU,AT,BE,BO,BR,BG,CA,CL,CO,CR,CY,CZ,DK,DO,D...          45
# 3  AR,AU,AT,BE,BO,BR,BG,CA,CL,CO,CR,CY,CZ,DK,DO,D...          69
# 4  AR,AU,AT,BE,BO,BR,BG,CA,CL,CO,CR,CY,CZ,DK,DO,D...          54
#
#                  track_id
# 0  6RUKPb4LETWmmr3iAEQktW
# 1  4tHqQMWSqmL6YjXwsqthDI
# 2  0HmONWWIU1FXkwWLDpqrjl
# 3  1dNIEtp7AY3oDAKCGg2XkH
# 4  0u8aj0c4IxeVSLTUuuq9V5

# %% [markdown]
# ## Merging dataframes

# %%
df_final = df_treated.merge(
    df_audio_features[["track_id", "acousticness", "danceability", "energy", "instrumentalness", "key", "liveness", "loudness", "mode", "speechiness", "tempo", "valence"]], # campos a serem trazidos do df_audio_features
    on="track_id", # track_id tem que tar na lista de cima
    how="left"
)

df_final = df_final.merge(
    df_multiple_track[["track_id", "popularity"]], # campos a serem trazidos do df_multiple_track
    on="track_id", # track_id tem que tar na lista de cima
    how="left"
)

# %%
df_final.to_csv("final_df.csv")
